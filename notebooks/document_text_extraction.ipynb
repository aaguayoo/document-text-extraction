# %%
# %load_ext autoreload
# %autoreload 2

# %%
from document_text_extraction.document_text_extraction import DocumentTextExtraction

# %%
extractor = DocumentTextExtraction("file.pdf")

# %%
extractor.extract_text()
