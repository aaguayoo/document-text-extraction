# %%
# %load_ext autoreload
# %autoreload 2

# %%
from document_text_extraction.text_extraction.pptx_text_extraction import (
    PPTXTextExtraction,
)

# %%
extractor = PPTXTextExtraction(file="file.pptx")

# %%
extractor.extract_text()
